# %% [markdown]
# # Storytelling with Data: a data visualization guide for business professionals
# 1. Understand the context
# 2. Choose an appropriate visual display
# 3. Eliminate clutter
# 4. Focus attention where you want it
# 5. Think like a designer
# 6. Tell a story
#
# # Chapter 1: Importance of context
# ### Exploratory analysis
# What you do to understant the data and figure out what might be noteworthy or interesting to highlight to others.
#
# ### Explanatory analysis
# After figure out important key points in the exploratory analysis, turn the data into information that can be consumed by an audience.
#
# ## 1.1 Who, what and how
# 1. To whom are you communicating?
#  - important to have a good understanding of who your audience is and how they perceive you.
#  - knowing well specific audience needs.
#  - establish good relationship with audience, it may impact the order and flow of the overall story you aim to tell.
# 2. What do you want your audience to know or do?
#  - how you want your audience to act and take into account how you will communicate to them and the overall tone that you want to set for your communication.
#  - How to make what you communicate relevant for your audience and forma clear understanding of why they should care what you say. How audience react with the communication.
#  - How will you communicate to your audience? - the method for communication.
# 3. How can you use data to help make your point?
#  - What data is available that will help to make my point?
#
# ### Glossary
# To build a communication, think about answering these questions for them up front:
#
# • What background information is relevant or essential?
#
# • Who is the audience or decision maker? What do we know about them?
#
# • What biases does our audience have that might make them supportive of or resistant to our message?
#
# • What data is available that would strengthen our case? Is our audience familiar with this data, or is it new?
#
# • Where are the risks: what factors could weaken our case and do we need to proactively address them?
#
# • What would a successful outcome look like?
#
# • If you only had a limited amount of time or a single sentence to tell your audience what they need to know, what would you say?
#
# # Chapter 2: Choosing an effective visual
# There are some visualization tools need to be avoided:
# - pie charts, donut charts, 3D, and secondary y-axes
#
# # Chapter 3: Clutter is your enemy
# ## 3.1. Cognitive load
# Perhaps without explicitly recognizing it, the presence of clutter in our visual communications can cause a less‐than‐ideal—or worse—uncomfortable user experience for our audience.
#
# Principles of visual perception:
# 1. Proximity
#  - arrange subjects as distinct groups or clusters.
# 2. Similarity
#  - Objects that are similar color, shape, size, or orientation are perceived as related or belonging to part of a group.
# 3. Enclosure
#  - The objects that are physically enclosed together as belonging to part of group. Highlight the importance of objects for purpose.
# 4. Closure
#  - The closure concept says that people like things to be simple and to fit the constructs that are already in our heads.
# 5. Continuity
#  - Similar to closure: when looking at objects, our eyes seek the smoothest path and naturally create continuity in what we see even where it may not explicitly exist.
# 6. Connection
#  - We tend to think of objects that are physically connected as part of a group. The connective property typically has a stronger associative value than similar color, size, or shape.
#
# ## 3.2. Lack of visual order
# Make the graph to the best look and highlight important information.
#
# ### Alignment
# The layout is arranged thoughtful that is easy to follow the context
# ### Decluttering
# Remove all unnecessary elements to drive confusion of attention
#
# # Chapter 4: focus your audience's attention
# Leading audience'attention from the macro to the micro parts of the story,e.g. changing bar's color for each desired level.
#
# Highlight one aspect can make other things harder to see.
#
# Color, size and front of text or graph in easy way to be attention
#
# # Chapter 5: think like a designer
# 1. Highlight the important stuff
#  - make the important stuff so special to see
# 2. Eliminate distractions
#  - know where is important info. to deliver to audience, and explain them in easy way to read.
# 3. Create a clear visual hierarchy of information
#  - grouping, categories elements in easy way to follow
# 4. Accessibility
#  - don't overcomplicate
# 5. Aesthetics
#  - be smart with color
#  - pay attention to alignment
#  - leverage white space
# 6. Acceptance
#  - Articulate the benefits of the new or different approach.
#  - Show the side-by-side
#  - Provide multiple options and seek input
#  - Get a vocal member of your audience on board
#
# # Chapter 6: dissecting model visual
# 1. line graph
#  - Everything is titled and labeled, so there is no question about what we looking at.
# 2. annotated line graph with forecast
#  - Numeric data labels are included for the forecast data points to give the audience clearly understanding of forward-looking expectations
# 3. 100% stacked bars
# 4. leveraging positive and negative stacked bars
# 5. horizontal stacked bars
#
# # Chapter 7: lession in storytelling
# 1. find a subject you care about
# 2. do not ramble, though
# 3. keep it simple
# 4. have the guts to cut
# 5. sound like yourself
# 6. say what you meant to say
# 7. pity the readers
#
# ### Tactics to help ensure that your story is clear
# 1. Horizontal logic
#  - The idea behind horizontal logic is that you can read just the slide title of each slide throughout your deck and, together, these snippets tell the overarching story you want to communicate. It is important to have action titles (not descriptive titles) for this to work well.
#  - e.g. slide a, b, c,..., summary
# 2. Vertical logic
#  - Vertical logic means that all information on a given slide is self‐reinforcing. The content reinforces the title and vice versa. The words reinforce the visual and vice versa. There isn’t any extraneous or unrelated information. Much of the time, the decision on what to eliminate or push to an appendix is as important (sometimes more so) as the decision on what to retain.
#  - e.g. Titled the topic, explanation and graph in one slide.
# 3. Reverse storyboarding
#  - When you storyboard at the onset of building a communication, you craft the outline of the story you intend to tell. As the name implies, reverse storyboarding does the opposite. You take the final communication, flip through it, and write down the main point from each page (it’s a nice way to test your horizontal logic as well). The resulting list should look like the storyboard or outline for the story you want to tell. If it doesn’t, this can help you understand structurally where you might want to add, remove, or move pieces around to create the overall flow and structure for the story that you’re interested in conveying.
#  - e.g. slide a, b, c for details, the final slide to drive the attention
#
# # Chapter 8: pulling it all together
# - understand the context
# - choose an appropriate display
# - eliminate clutter
# - Draw attention where you want it
# - think like a designer
# - tell a story, e.g.:
#  - understand how prices have changed over time in the competive landscape.
#  - use this knowledge to inform the pricing of our product
#  - end with a specific recommendation
#
# # Chapter 9: case studies
